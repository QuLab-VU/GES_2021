# %%
import pandas as pd
import numpy as np

# %%
df_DS8_ER1 = pd.read_pickle('PC9-DS8_param-scan_twoState_highDivsMoreDIP_expandedRange1.pkl')
df_DS8_ER2 = pd.read_pickle('PC9-DS8_param-scan_twoState_highDivsMoreDIP_expandedRange2.pkl')
df_DS8_ER3 = pd.read_pickle('PC9-DS8_param-scan_twoState_highDivsMoreDIP_expandedRange3.pkl')
df_DS8_ER4 = pd.read_pickle('PC9-DS8_param-scan_twoState_highDivsMoreDIP_expandedRange4.pkl')
df_DS8_ER5 = pd.read_pickle('PC9-DS8_param-scan_twoState_highDivsMoreDIP_expandedRange5.pkl')
df_DS8_ER6 = pd.read_pickle('PC9-DS8_param-scan_twoState_highDivsMoreDIP_expandedRange6.pkl')
df_DS8_ER7 = pd.read_pickle('PC9-DS8_param-scan_twoState_highDivsMoreDIP_expandedRange7.pkl')
df_DS8_ER8 = pd.read_pickle('PC9-DS8_param-scan_twoState_highDivsMoreDIP_expandedRange8.pkl')

# %%
df_DS8_ER1['cell.line'] = 'PC9.DS8'
df_DS8_ER2['cell.line'] = 'PC9.DS8'
df_DS8_ER3['cell.line'] = 'PC9.DS8'
df_DS8_ER4['cell.line'] = 'PC9.DS8'
df_DS8_ER5['cell.line'] = 'PC9.DS8'
df_DS8_ER6['cell.line'] = 'PC9.DS8'
df_DS8_ER7['cell.line'] = 'PC9.DS8'
df_DS8_ER8['cell.line'] = 'PC9.DS8'

# %%
### ER1
DS8_dipdf_ER1 = pd.DataFrame(df_DS8_ER1['DIP rate'].values.tolist(), columns=['DIP1','DIP2'])
DS8_divdf_ER1 = pd.DataFrame(df_DS8_ER1['division rate'].values.tolist(), columns=['div1','div2'])
DS8_dthdf_ER1 = pd.DataFrame(df_DS8_ER1['death rate'].values.tolist(), columns=['dth1','dth2'])
DS8_rest_ER1 = df_DS8_ER1[['p-value', 'cell.line']]
DS8_rest_ER1.reset_index(drop=True)

### ER2
DS8_dipdf_ER2 = pd.DataFrame(df_DS8_ER2['DIP rate'].values.tolist(), columns=['DIP1','DIP2'])
DS8_divdf_ER2 = pd.DataFrame(df_DS8_ER2['division rate'].values.tolist(), columns=['div1','div2'])
DS8_dthdf_ER2 = pd.DataFrame(df_DS8_ER2['death rate'].values.tolist(), columns=['dth1','dth2'])
DS8_rest_ER2 = df_DS8_ER2[['p-value', 'cell.line']]
DS8_rest_ER2.reset_index(drop=True)

### ER3
DS8_dipdf_ER3 = pd.DataFrame(df_DS8_ER3['DIP rate'].values.tolist(), columns=['DIP1','DIP2'])
DS8_divdf_ER3 = pd.DataFrame(df_DS8_ER3['division rate'].values.tolist(), columns=['div1','div2'])
DS8_dthdf_ER3 = pd.DataFrame(df_DS8_ER3['death rate'].values.tolist(), columns=['dth1','dth2'])
DS8_rest_ER3 = df_DS8_ER3[['p-value', 'cell.line']]
DS8_rest_ER3.reset_index(drop=True)

### ER4
DS8_dipdf_ER4 = pd.DataFrame(df_DS8_ER4['DIP rate'].values.tolist(), columns=['DIP1','DIP2'])
DS8_divdf_ER4 = pd.DataFrame(df_DS8_ER4['division rate'].values.tolist(), columns=['div1','div2'])
DS8_dthdf_ER4 = pd.DataFrame(df_DS8_ER4['death rate'].values.tolist(), columns=['dth1','dth2'])
DS8_rest_ER4 = df_DS8_ER4[['p-value', 'cell.line']]
DS8_rest_ER4.reset_index(drop=True)

### ER5
DS8_dipdf_ER5 = pd.DataFrame(df_DS8_ER5['DIP rate'].values.tolist(), columns=['DIP1','DIP2'])
DS8_divdf_ER5 = pd.DataFrame(df_DS8_ER5['division rate'].values.tolist(), columns=['div1','div2'])
DS8_dthdf_ER5 = pd.DataFrame(df_DS8_ER5['death rate'].values.tolist(), columns=['dth1','dth2'])
DS8_rest_ER5 = df_DS8_ER5[['p-value', 'cell.line']]
DS8_rest_ER5.reset_index(drop=True)

### ER6
DS8_dipdf_ER6 = pd.DataFrame(df_DS8_ER6['DIP rate'].values.tolist(), columns=['DIP1','DIP2'])
DS8_divdf_ER6 = pd.DataFrame(df_DS8_ER6['division rate'].values.tolist(), columns=['div1','div2'])
DS8_dthdf_ER6 = pd.DataFrame(df_DS8_ER6['death rate'].values.tolist(), columns=['dth1','dth2'])
DS8_rest_ER6 = df_DS8_ER6[['p-value', 'cell.line']]
DS8_rest_ER6.reset_index(drop=True)

### ER7
DS8_dipdf_ER7 = pd.DataFrame(df_DS8_ER7['DIP rate'].values.tolist(), columns=['DIP1','DIP2'])
DS8_divdf_ER7 = pd.DataFrame(df_DS8_ER7['division rate'].values.tolist(), columns=['div1','div2'])
DS8_dthdf_ER7 = pd.DataFrame(df_DS8_ER7['death rate'].values.tolist(), columns=['dth1','dth2'])
DS8_rest_ER7 = df_DS8_ER7[['p-value', 'cell.line']]
DS8_rest_ER7.reset_index(drop=True)

### ER8
DS8_dipdf_ER8 = pd.DataFrame(df_DS8_ER8['DIP rate'].values.tolist(), columns=['DIP1','DIP2'])
DS8_divdf_ER8 = pd.DataFrame(df_DS8_ER8['division rate'].values.tolist(), columns=['div1','div2'])
DS8_dthdf_ER8 = pd.DataFrame(df_DS8_ER8['death rate'].values.tolist(), columns=['dth1','dth2'])
DS8_rest_ER8 = df_DS8_ER8[['p-value', 'cell.line']]
DS8_rest_ER8.reset_index(drop=True)
# Out:
#        p-value cell.line
# 0     0.001605   PC9.DS8
# 1     0.055891   PC9.DS8
# 2     0.000736   PC9.DS8
# 3     0.000269   PC9.DS8
# 4     0.000744   PC9.DS8
# ...        ...       ...
# 1645  0.159150   PC9.DS8
# 1646  0.001916   PC9.DS8
# 1647  0.280283   PC9.DS8
# 1648  0.004416   PC9.DS8
# 1649  0.142694   PC9.DS8
#
# [1650 rows x 2 columns]

# %%
DS8_ER1 = pd.concat([DS8_rest_ER1.reset_index(drop=True), 
                     DS8_dipdf_ER1.reset_index(drop=True), 
                     DS8_divdf_ER1.reset_index(drop=True),
                     DS8_dthdf_ER1], axis = 1)

DS8_ER2 = pd.concat([DS8_rest_ER2.reset_index(drop=True), 
                     DS8_dipdf_ER2.reset_index(drop=True), 
                     DS8_divdf_ER2.reset_index(drop=True),
                     DS8_dthdf_ER2], axis = 1)

DS8_ER3 = pd.concat([DS8_rest_ER3.reset_index(drop=True), 
                     DS8_dipdf_ER3.reset_index(drop=True), 
                     DS8_divdf_ER3.reset_index(drop=True),
                     DS8_dthdf_ER3], axis = 1)

DS8_ER4 = pd.concat([DS8_rest_ER4.reset_index(drop=True), 
                     DS8_dipdf_ER4.reset_index(drop=True), 
                     DS8_divdf_ER4.reset_index(drop=True),
                     DS8_dthdf_ER4], axis = 1)

DS8_ER5 = pd.concat([DS8_rest_ER5.reset_index(drop=True), 
                     DS8_dipdf_ER5.reset_index(drop=True), 
                     DS8_divdf_ER5.reset_index(drop=True),
                     DS8_dthdf_ER5], axis = 1)

DS8_ER6 = pd.concat([DS8_rest_ER6.reset_index(drop=True), 
                     DS8_dipdf_ER6.reset_index(drop=True), 
                     DS8_divdf_ER6.reset_index(drop=True),
                     DS8_dthdf_ER6], axis = 1)

DS8_ER7 = pd.concat([DS8_rest_ER7.reset_index(drop=True), 
                     DS8_dipdf_ER7.reset_index(drop=True), 
                     DS8_divdf_ER7.reset_index(drop=True),
                     DS8_dthdf_ER7], axis = 1)

DS8_ER8 = pd.concat([DS8_rest_ER8.reset_index(drop=True), 
                     DS8_dipdf_ER8.reset_index(drop=True), 
                     DS8_divdf_ER8.reset_index(drop=True),
                     DS8_dthdf_ER8], axis = 1)

# %%
DS8_all_ER = pd.concat([DS8_ER1, DS8_ER2, DS8_ER3, DS8_ER4,
                      DS8_ER5, DS8_ER6, DS8_ER7, DS8_ER8], ignore_index = True)
DS8 = DS8_all_ER

# %%
DS8.head()
# Out:
#     p-value     cell.line    DIP1    DIP2   div1   div2    dth1    dth2  \
# 0  0.003035  not.assigned  0.0005  0.0055  0.041  0.041  0.0405  0.0355
# 1  0.004728  not.assigned  0.0005  0.0057  0.041  0.041  0.0405  0.0353
# 2  0.003969  not.assigned  0.0005  0.0059  0.041  0.041  0.0405  0.0351
# 3  0.005374  not.assigned  0.0005  0.0061  0.041  0.041  0.0405  0.0349
# 4  0.001508  not.assigned  0.0005  0.0063  0.041  0.041  0.0405  0.0347
#
#    param.pair
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4

# %%
## Annotate with modified identifier (ease of plotting)
DS8['cell.line'] = np.where(DS8['p-value']>0.1, 'PC9-DS8', 'not.assigned')
DS8['param.pair'] = range(DS8.shape[0])

# %%
## Create subsets of data frame (see below)
DS8_sig1 = DS8[['p-value', 'cell.line', 'DIP1', 'div1', 'dth1', 'param.pair']]
DS8_sig2 = DS8[['p-value', 'cell.line', 'DIP2', 'div2', 'dth2', 'param.pair']]

# %%
DS8_sig1.head()
# Out:
#     p-value     cell.line  DIP Rate  Division Rate  Death Rate  param.pair
# 0  0.003035  not.assigned    0.0005          0.041      0.0405           0
# 1  0.004728  not.assigned    0.0005          0.041      0.0405           1
# 2  0.003969  not.assigned    0.0005          0.041      0.0405           2
# 3  0.005374  not.assigned    0.0005          0.041      0.0405           3
# 4  0.001508  not.assigned    0.0005          0.041      0.0405           4

# %%
## Rename columns of data frame subsets
DS8_sig1.rename(columns={'DIP1': 'DIP Rate',
                         'div1': 'Division Rate',
                         'dth1': 'Death Rate'},
                 inplace=True)
DS8_sig2.rename(columns={'DIP2': 'DIP Rate',
                         'div2': 'Division Rate',
                         'dth2': 'Death Rate'},
                inplace=True)
# Out:
# /Users/Corey/anaconda2/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py:4223: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(**kwargs)

# %%
## Separate subsets based on which DS8 state it resides in
DS8_sig1['Cell Line'] = np.where(DS8_sig1['cell.line'] == "PC9-DS8", 'PC9-DS8.1', 'not.assigned')
DS8_sig2['Cell Line'] = np.where(DS8_sig2['cell.line'] == "PC9-DS8", 'PC9-DS8.2', 'not.assigned')

## Concatenate datasets back together
DS8_sig_all = pd.concat([DS8_sig1, DS8_sig2])
# Out:
# /Users/Corey/anaconda2/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/Corey/anaconda2/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
DS8_sig_all.head()
# Out:
#     p-value     cell.line  DIP Rate  Division Rate  Death Rate  param.pair  \
# 0  0.003035  not.assigned    0.0005          0.041      0.0405           0
# 1  0.004728  not.assigned    0.0005          0.041      0.0405           1
# 2  0.003969  not.assigned    0.0005          0.041      0.0405           2
# 3  0.005374  not.assigned    0.0005          0.041      0.0405           3
# 4  0.001508  not.assigned    0.0005          0.041      0.0405           4
#
#       Cell Line
# 0  not.assigned
# 1  not.assigned
# 2  not.assigned
# 3  not.assigned
# 4  not.assigned

# %%
DS8_sig_all.to_csv('DS8_twoState_tile_wholeRange_ER.csv')
